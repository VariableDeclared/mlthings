# %%
# !pip install keras-cv matplotlib
# Out:
# Requirement already satisfied: keras-cv in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (0.8.1)
# Collecting matplotlib
#   Downloading matplotlib-3.8.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Requirement already satisfied: packaging in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from keras-cv) (23.1)
# Requirement already satisfied: absl-py in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from keras-cv) (2023.10.3)
# Requirement already satisfied: tensorflow-datasets in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from keras-cv) (4.9.4)
# Requirement already satisfied: keras-core in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from keras-cv) (0.1.7)
# Requirement already satisfied: kagglehub in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from keras-cv) (0.1.6)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.47.2-cp310-cp310-macosx_10_9_universal2.whl.metadata (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.6/157.6 kB 3.7 MB/s eta 0:00:000:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.2.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: requests in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from kagglehub->keras-cv) (2.31.0)
# Requirement already satisfied: tqdm in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from kagglehub->keras-cv) (4.65.0)
# Requirement already satisfied: rich in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from keras-core->keras-cv) (13.7.0)
# Requirement already satisfied: namex in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from keras-core->keras-cv) (0.0.7)
# Requirement already satisfied: h5py in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from keras-core->keras-cv) (3.9.0)
# Requirement already satisfied: dm-tree in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: etils>=0.9.0 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras-cv) (1.6.0)
# Requirement already satisfied: promise in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (3.20.3)
# Requirement already satisfied: psutil in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (5.9.0)
# Requirement already satisfied: tensorflow-metadata in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (1.14.0)
# Requirement already satisfied: termcolor in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (2.1.0)
# Requirement already satisfied: toml in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (1.14.1)
# Requirement already satisfied: fsspec in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras-cv) (2023.10.0)
# Requirement already satisfied: importlib_resources in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras-cv) (6.1.1)
# Requirement already satisfied: typing_extensions in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras-cv) (4.9.0)
# Requirement already satisfied: zipp in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras-cv) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from requests->kagglehub->keras-cv) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from requests->kagglehub->keras-cv) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from requests->kagglehub->keras-cv) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from requests->kagglehub->keras-cv) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from rich->keras-core->keras-cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from rich->keras-core->keras-cv) (2.15.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.62.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/peterdesousa/miniconda3/envs/tensorflow-notebooks/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)
# Downloading matplotlib-3.8.2-cp310-cp310-macosx_11_0_arm64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 37.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading contourpy-1.2.0-cp310-cp310-macosx_11_0_arm64.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.2/242.2 kB 7.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.47.2-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 29.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 1.9 MB/s eta 0:00:00
# Downloading pillow-10.2.0-cp310-cp310-macosx_11_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 38.3 MB/s eta 0:00:00m eta 0:00:010:01
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.47.2 kiwisolver-1.4.5 matplotlib-3.8.2 pillow-10.2.0 pyparsing-3.1.1

# %%
import time
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend

# %%
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
images = model.text_to_image("point of view of a person racing a car", batch_size=3)


def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")


plot_images(images)
# Out:
# 2024-01-27 14:37:19.822601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype int32 and shape [1,77]
# 	 [[{{node Placeholder/_1}}]]
# 2024-01-27 14:37:19.912524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype int32 and shape [1,77]
# 	 [[{{node Placeholder/_1}}]]
# 2024-01-27 14:37:19.986263: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:37:27.393913: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
#  1/50 [..............................] - ETA: 12:08
# 2024-01-27 14:37:34.854812: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:37:41.984045: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
#  2/50 [>.............................] - ETA: 11:25
# 2024-01-27 14:37:49.143928: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:37:56.253898: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
#  3/50 [>.............................] - ETA: 11:10
# 2024-01-27 14:38:03.401920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:38:10.534166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
#  4/50 [=>............................] - ETA: 10:56
# 2024-01-27 14:38:17.651178: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:38:24.807984: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
#  5/50 [==>...........................] - ETA: 10:42
# 2024-01-27 14:38:32.009446: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:38:39.201434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
#  6/50 [==>...........................] - ETA: 10:29
# 2024-01-27 14:38:46.414497: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:38:53.583727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
#  7/50 [===>..........................] - ETA: 10:15
# 2024-01-27 14:39:00.724849: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:39:07.911836: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
#  8/50 [===>..........................] - ETA: 10:01
# 2024-01-27 14:39:15.137382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:39:22.369366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
#  9/50 [====>.........................] - ETA: 9:47
# 2024-01-27 14:39:29.540452: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:39:36.766818: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 10/50 [=====>........................] - ETA: 9:33
# 2024-01-27 14:39:43.945914: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:39:51.216684: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 11/50 [=====>........................] - ETA: 9:20
# 2024-01-27 14:39:58.455976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:40:05.672366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 12/50 [======>.......................] - ETA: 9:05
# 2024-01-27 14:40:12.906251: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:40:20.180088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 13/50 [======>.......................] - ETA: 8:52
# 2024-01-27 14:40:27.396149: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
# 2024-01-27 14:40:34.663100: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,320]
# 	 [[{{node Placeholder/_2}}]]
#